# %% [markdown]
# Knowledge Graph Based Chatbot

# %%
import nltk
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random


import nltk
nltk.download('punkt')

import nltk
nltk.download('wordnet')

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
# data_file = open('intents.json').read()
# intents = json.loads(data_file)

with open(r"/content/json_data.json","r") as json_data:
    intents = json.load(json_data)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
# classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(256, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

model.summary()
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

####epochs
no_epochs=200
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=no_epochs, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")



import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random


with open(r"/content/json_data.json","r") as json_data:
    intents = json.load(json_data)

words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
from collections import defaultdict

dic=defaultdict(str)


qs=["Hi","Hello","Good Morning"]
dic["Hi"]="Hi, I am Eva the knowledge based ChatBot, How can I help you?"
dic["Hello"]="Hello, I am Eva the knowledge based ChatBot, How can I help you?"
dic["Good Morning"]="Good Morning, I wish you a good day, How can I help you?"


def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # print(sentence_words)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    # print("Model result: ", res)
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    # print("results are: ", results)
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            # print("our tag ",tag)
            # print("i: ", i['tag'], i['responses'])
            # print("i[responses]: ")
            # print(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    # print("ints are: ", ints)
    if len(ints)==0:
      return "Sorry, I didn't get you, can you please ask in another way?"
    res = getResponse(ints, intents)
    return res


print("---------------------------------Chtabot starts----------------------\n")
print("------------------------If you want to stop chatting, enter exit-------------\n")
while True:
  s=input()
  if s=='exit':
    break
  if s in qs:
    print(dic[s])
  else:
    s=s.strip()
    res=chatbot_response(s)
    print(res)
# Out:
# 206 documents
# 110 classes [['incubation_corona'], ['corona'], ['symptoms_corona'], ['vaccine'], ['treatment_corona'], ['protect'], ['worker_risk'], ['WHO'], ['risk_corona'], ['test_doctor'], ['covid_SARS'], ['SARS'], ['transmission_corona'], ['infectious'], ['infection'], ['risk'], ['risk_transmission'], ['risk_pregnant'], ['test_covid'], ['test'], ['allergy_covid'], ['allergy_symptoms'], ['avoid_infecting'], ['distancing'], ['mask_covid'], ['covid_influenza'], ['europe_covid'], ['EU'], ['peak'], ['schools'], ['restriction'], ['travel'], ['food'], ['animal'], ['lung'], ['measure'], ['isolate'], ['safe'], ['covid'], ['fever'], ['mask'], ['smoke'], ['condition'], ['flu_vaccine'], ['vulnerable'], ['Europe'], ['faces'], ['catch'], ['worry'], ['antibiotic'], ['medicine'], ['incubation'], ['package'], ['not_do'], ['symptoms'], ['second'], ['virus'], ['illness'], ['again'], ['spread'], ['medical'], ['reduce_infection'], ['ibuprofen'], ['house'], ['medical_appointment'], ['home'], ['worker home'], ['work'], ['friends'], ['relatives'], ['park'], ['drive'], ['rules'], ['intercollegiate'], ['teaching'], ['pregnant'], ['baby'], ['appointment'], [' pregnant'], ['child'], ['birth'], ['testing'], ['labour'], ['corona_virus'], ['stigma'], ['rise'], ['weather'], ['community'], ['temperature'], ['mosquitoes'], ['contact'], ['donate'], ['child_covid'], ['child_mask'], ['family'], ['sick'], ['sanitizer'], ['risk corona'], ['prevent'], ['treatment'], ['transmitted'], ['animlas'], ['pets'], ['incubarion'], ['worry_covid'], ['use_of_mask'], ['animal_source'], ['pet'], ['government'], ['information']]
# 448 unique lemmatized words ['(', ')', ',', '.', '14', '2019', ';', 'a', 'able', 'about', 'accurate', 'additional', 'adult', 'advice', 'affect', 'affected', 'after', 'again', 'against', 'age', 'air', 'allergy', 'allowed', 'also', 'am', 'an', 'and', 'animal', 'another', 'antenatal', 'antibiotic', 'any', 'anything', 'appointment', 'are', 'area', 'asked', 'at', 'attend', 'attention', 'available', 'avoid', 'baby', 'be', 'because', 'become', 'becoming', 'been', 'being', 'between', 'birth', 'blame', 'blood', 'both', 'break', 'by', 'ca', 'caesarean', 'called', 'can', 'cancer', 'care', 'case', 'catch', 'catching', 'caught', 'cause', 'cdc', 'centre', 'chain', 'child', 'childbirth', 'china', 'choice', 'cleaning', 'close', 'closed', 'come', 'community', 'comparable', 'complication', 'condition', 'confirmed', 'consider', 'contact', 'contain', 'continuing', 'control', 'corona', 'coronavirus', 'cough', 'could', 'country', 'covering', 'covid-19', 'covid19', 'create', 'critical', 'crowded', 'cure', 'day', 'dentist', 'detailed', 'develop', 'developing', 'diagnosed', 'die', 'different', 'differentiate', 'disease', 'dispose', 'distancing', 'distinguish', 'do', 'doctor', 'doe', 'doesn', 'doing', 'donate', 'done', 'drive', 'drug', 'dry', 'during', 'e.g', 'effect', 'effective', 'elderly', 'essential', 'etc', 'eu', 'eu/eea', 'europe', 'european', 'every', 'exhaled', 'face', 'family', 'fda-approved', 'feces', 'feel', 'fever', 'fever/pollen', 'find', 'flu', 'food', 'for', 'friend', 'from', 'frozen', 'garden', 'general', 'germ', 'get', 'getting', 'give', 'go', 'government', 'gp', 'green', 'group', 'ha', 'had', 'hall', 'hand', 'handling', 'happen', 'happens', 'have', 'having', 'hay', 'health', 'help', 'high', 'higher', 'home', 'house', 'how', 'human', 'i', 'ibuprofen', 'if', 'illness', 'impact', 'imported', 'in', 'including', 'incubation', 'individual', 'induced', 'infected', 'infecting', 'infection', 'infectious', 'influenza', 'information', 'instrumental', 'intercollegiate', 'into', 'is', 'isolate', 'it', 'kill', 'know', 'labour', 'last', 'leave', 'like', 'likely', 'limit', 'live', 'logistics', 'long', 'lung', 'm', 'major', 'make', 'managed', 'many', 'mask', 'me', 'measure', 'median', 'medical', 'medicine', 'member', 'might', 'mode', 'moment', 'more', 'mosquito', 'most', 'move', 'my', 'myself', "n't", 'national', 'need', 'neighbour', 'neonate', 'news', 'no', 'not', 'novel', 'obtain', 'occurs', 'of', 'off', 'often', 'okay', 'older', 'on', 'one', 'open', 'operating', 'opposed', 'or', 'organisation', 'other', 'others', 'our', 'out', 'outbreak', 'outside', 'own', 'package', 'packaged', 'pandemic', 'park', 'part', 'partner', 'pas', 'past', 'peak', 'people', 'period', 'person', 'pet', 'physical', 'plane', 'please', 'pollen', 'population', 'positive', 'possible', 'postnatal', 'potential', 'pre-existing', 'precaution', 'pregnancy', 'pregnant', 'prepare', 'prepared', 'prevent', 'preventing', 'product', 'protect', 'protected', 'protecting', 'protection', 'provide', 'provided', 'put', 'receive', 'recently', 'recommend', 'recommendation', 'recovered', 'reduce', 'reducing', 'refer', 'refrigerated', 'regularly', 'related', 'relative', 'reported', 'residence', 'respiratory', 'restaurant', 'restriction', 'retail', 'rise', 'risk', 'role', 'rule', 'safe', 'same', 'sanitizer', 'sars', 'sars-cov-2', 'say', 'school', 'scientific', 'seasonal', 'second', 'see', 'seeing', 'self', 'self-isolate', 'self-isolating', 'self-isolation', 'serious', 'service', 'setting', 'severe', 'shipping', 'should', 'show', 'sick', 'situation', 'smoke', 'soap', 'social', 'some', 'somebody', 'someone', 'source', 'space', 'spread', 'spreading', 'standpoint', 'stay', 'step', 'stigma', 'stop', 'store', 'student', 'suffer', 'suffering', 'supply', 'surface', 'survive', 'suspected', 'symptom', 't', 'take', 'taken', 'teaching', 'temperature', 'test', 'tested', 'than', 'that', 'the', 'theatre', 'their', 'therapy', 'there', 'these', 'they', 'this', 'those', 'through', 'time', 'to', 'transmission', 'transmi ...
# Training data created
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               114944
#
#  dropout_2 (Dropout)         (None, 256)               0
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:84: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 110)               14190
#
# =================================================================
# Total params: 162,030
# Trainable params: 162,030
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 42/42 [==============================] - 1s 2ms/step - loss: 4.7363 - accuracy: 0.0097
# Epoch 2/200
# 42/42 [==============================] - 0s 3ms/step - loss: 4.5492 - accuracy: 0.0631
# Epoch 3/200
# 42/42 [==============================] - 0s 2ms/step - loss: 4.3718 - accuracy: 0.0777
# Epoch 4/200
# 42/42 [==============================] - 0s 2ms/step - loss: 4.2090 - accuracy: 0.1068
# Epoch 5/200
# 42/42 [==============================] - 0s 3ms/step - loss: 3.9653 - accuracy: 0.1359
# Epoch 6/200
# 42/42 [==============================] - 0s 2ms/step - loss: 3.7666 - accuracy: 0.1796
# Epoch 7/200
# 42/42 [==============================] - 0s 2ms/step - loss: 3.5207 - accuracy: 0.2233
# Epoch 8/200
# 42/42 [==============================] - 0s 2ms/step - loss: 3.3779 - accuracy: 0.2573
# Epoch 9/200
# 42/42 [==============================] - 0s 2ms/step - loss: 3.1099 - accuracy: 0.2961
# Epoch 10/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.9376 - accuracy: 0.3495
# Epoch 11/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.7640 - accuracy: 0.3495
# Epoch 12/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.6310 - accuracy: 0.3544
# Epoch 13/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.4752 - accuracy: 0.4126
# Epoch 14/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.2175 - accuracy: 0.4709
# Epoch 15/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.0238 - accuracy: 0.5194
# Epoch 16/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.9877 - accuracy: 0.4951
# Epoch 17/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.8998 - accuracy: 0.5146
# Epoch 18/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.8553 - accuracy: 0.4951
# Epoch 19/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.6067 - accuracy: 0.5777
# Epoch 20/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.5548 - accuracy: 0.5485
# Epoch 21/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.4997 - accuracy: 0.6214
# Epoch 22/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.2865 - accuracy: 0.6650
# Epoch 23/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.2740 - accuracy: 0.6408
# Epoch 24/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.9877 - accuracy: 0.7718
# Epoch 25/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1140 - accuracy: 0.7039
# Epoch 26/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.0925 - accuracy: 0.7184
# Epoch 27/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1599 - accuracy: 0.6699
# Epoch 28/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.0074 - accuracy: 0.7330
# Epoch 29/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9535 - accuracy: 0.7330
# Epoch 30/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.8280 - accuracy: 0.7864
# Epoch 31/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.8741 - accuracy: 0.7427
# Epoch 32/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9374 - accuracy: 0.7330
# Epoch 33/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7838 - accuracy: 0.7961
# Epoch 34/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7566 - accuracy: 0.8010
# Epoch 35/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7735 - accuracy: 0.7913
# Epoch 36/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.8519 - accuracy: 0.7816
# Epoch 37/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7963 - accuracy: 0.7961
# Epoch 38/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7451 - accuracy: 0.7864
# Epoch 39/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.8226 - accuracy: 0.7767
# Epoch 40/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7006 - accuracy: 0.8010
# Epoch 41/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6298 - accuracy: 0.8350
# Epoch 42/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.8204
# Epoch 43/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5130 - accuracy: 0.8544
# Epoch 44/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7000 - accuracy: 0.8204
# Epoch 45/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5169 - accuracy: 0.8155
# Epoch 46/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.8641
# Epoch 47/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5757 - accuracy: 0.8350
# Epoch 48/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5906 - accuracy: 0.8641
# Epoch 49/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4443 - accuracy: 0.8544
# Epoch 50/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6493 - accuracy: 0.8010
# Epoch 51/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.8350
# Epoch 52/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4617 - accuracy: 0.8301
# Epoch 53/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4486 - accuracy: 0.8592
# Epoch 54/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5323 - accuracy: 0.8495
# Epoch 55/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.8252
# Epoch 56/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5097 - accuracy: 0.8592
# Epoch 57/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.8495
# Epoch 58/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5205 - accuracy: 0.8398
# Epoch 59/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4604 - accuracy: 0.8544
# Epoch 60/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.8350
# Epoch 61/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4789 - accuracy: 0.8835
# Epoch 62/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.8495
# Epoch 63/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.8641
# Epoch 64/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.9223
# Epoch 65/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3750 - accuracy: 0.9029
# Epoch 66/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3567 - accuracy: 0.8932
# Epoch 67/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3396 - accuracy: 0.8786
# Epoch 68/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3203 - accuracy: 0.8981
# Epoch 69/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3912 - accuracy: 0.8641
# Epoch 70/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3498 - accuracy: 0.8883
# Epoch 71/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8883
# Epoch 72/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3026 - accuracy: 0.8883
# Epoch 73/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8883
# Epoch 74/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8981
# Epoch 75/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8981
# Epoch 76/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3049 - accuracy: 0.8932
# Epoch 77/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3381 - accuracy: 0.9078
# Epoch 78/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.8981
# Epoch 79/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8641
# Epoch 80/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4516 - accuracy: 0.8592
# Epoch 81/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.8544
# Epoch 82/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.8786
# Epoch 83/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4937 - accuracy: 0.8301
# Epoch 84/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8689
# Epoch 85/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3213 - accuracy: 0.9029
# Epoch 86/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8932
# Epoch 87/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.9126
# Epoch 88/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4872 - accuracy: 0.8592
# Epoch 89/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3386 - accuracy: 0.8738
# Epoch 90/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8883
# Epoch 91/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3862 - accuracy: 0.8786
# Epoch 92/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.9078
# Epoch 93/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3295 - accuracy: 0.8981
# Epoch 94/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3188 - accuracy: 0.9078
# Epoch 95/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4311 - accuracy: 0.8883
# Epoch 96/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2728 - accuracy: 0.8932
# Epoch 97/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3653 - accuracy: 0.8738
# Epoch 98/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8932
# Epoch 99/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8981
# Epoch 100/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8932
# Epoch 101/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8883
# Epoch 102/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8835
# Epoch 103/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8981
# Epoch 104/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8786
# Epoch 105/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8738
# Epoch 106/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2754 - accuracy: 0.9126
# Epoch 107/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2416 - accuracy: 0.9029
# Epoch 108/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8981
# Epoch 109/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2714 - accuracy: 0.9126
# Epoch 110/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3015 - accuracy: 0.8932
# Epoch 111/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2852 - accuracy: 0.9320
# Epoch 112/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8883
# Epoch 113/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8786
# Epoch 114/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2882 - accuracy: 0.9078
# Epoch 115/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8495
# Epoch 116/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2790 - accuracy: 0.8883
# Epoch 117/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8641
# Epoch 118/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3179 - accuracy: 0.8932
# Epoch 119/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2242 - accuracy: 0.9175
# Epoch 120/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2557 - accuracy: 0.9175
# Epoch 121/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8932
# Epoch 122/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.8786
# Epoch 123/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8641
# Epoch 124/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2990 - accuracy: 0.8786
# Epoch 125/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2956 - accuracy: 0.9078
# Epoch 126/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2902 - accuracy: 0.8981
# Epoch 127/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2228 - accuracy: 0.9417
# Epoch 128/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3017 - accuracy: 0.8981
# Epoch 129/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2916 - accuracy: 0.8981
# Epoch 130/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2944 - accuracy: 0.9175
# Epoch 131/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2882 - accuracy: 0.8883
# Epoch 132/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2469 - accuracy: 0.8932
# Epoch 133/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 0.9175
# Epoch 134/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2611 - accuracy: 0.9078
# Epoch 135/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.8883
# Epoch 136/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.8835
# Epoch 137/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2891 - accuracy: 0.8932
# Epoch 138/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.8981
# Epoch 139/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2974 - accuracy: 0.8932
# Epoch 140/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2236 - accuracy: 0.9272
# Epoch 141/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.9126
# Epoch 142/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.9320
# Epoch 143/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.9029
# Epoch 144/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9417
# Epoch 145/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3258 - accuracy: 0.8883
# Epoch 146/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.9029
# Epoch 147/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2333 - accuracy: 0.9175
# Epoch 148/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2843 - accuracy: 0.8786
# Epoch 149/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2850 - accuracy: 0.9029
# Epoch 150/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2850 - accuracy: 0.8981
# Epoch 151/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2692 - accuracy: 0.8883
# Epoch 152/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2926 - accuracy: 0.9029
# Epoch 153/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2102 - accuracy: 0.9320
# Epoch 154/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2897 - accuracy: 0.8883
# Epoch 155/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2322 - accuracy: 0.9320
# Epoch 156/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2439 - accuracy: 0.9223
# Epoch 157/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1885 - accuracy: 0.9272
# Epoch 158/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2079 - accuracy: 0.9272
# Epoch 159/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3041 - accuracy: 0.9078
# Epoch 160/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8786
# Epoch 161/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2573 - accuracy: 0.8981
# Epoch 162/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2581 - accuracy: 0.8883
# Epoch 163/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2560 - accuracy: 0.8981
# Epoch 164/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2403 - accuracy: 0.9078
# Epoch 165/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.9029
# Epoch 166/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.8981
# Epoch 167/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2181 - accuracy: 0.9320
# Epoch 168/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.9175
# Epoch 169/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9515
# Epoch 170/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.8932
# Epoch 171/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2573 - accuracy: 0.9223
# Epoch 172/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3064 - accuracy: 0.9029
# Epoch 173/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9466
# Epoch 174/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9272
# Epoch 175/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2511 - accuracy: 0.9223
# Epoch 176/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2091 - accuracy: 0.9272
# Epoch 177/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.9078
# Epoch 178/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2104 - accuracy: 0.9223
# Epoch 179/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2095 - accuracy: 0.9369
# Epoch 180/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9175
# Epoch 181/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1979 - accuracy: 0.9369
# Epoch 182/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2607 - accuracy: 0.9029
# Epoch 183/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1334 - accuracy: 0.9466
# Epoch 184/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2267 - accuracy: 0.9272
# Epoch 185/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.9029
# Epoch 186/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9078
# Epoch 187/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3024 - accuracy: 0.9078
# Epoch 188/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2655 - accuracy: 0.8981
# Epoch 189/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2850 - accuracy: 0.8932
# Epoch 190/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2369 - accuracy: 0.8981
# Epoch 191/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2084 - accuracy: 0.9078
# Epoch 192/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2729 - accuracy: 0.8981
# Epoch 193/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9369
# Epoch 194/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1638 - accuracy: 0.9515
# Epoch 195/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2038 - accuracy: 0.9175
# Epoch 196/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2229 - accuracy: 0.9272
# Epoch 197/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9272
# Epoch 198/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8981
# Epoch 199/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9175
# Epoch 200/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.9223
# model created
# ---------------------------------Chtabot starts----------------------
#
# ------------------------If you want to stop chatting, enter exit-------------
#
# Hi
# Hi, I am Eva the knowledge based ChatBot, How can I help you?
# What is incubation period of corona virus?
# The incubation period means the time between catching the virus and beginning to have symptoms of the disease. Most estimates of the incubation period for COVID-19 range from 1-14 days, most commonly around five days. These estimates will be updated as more data become available.
# exit
